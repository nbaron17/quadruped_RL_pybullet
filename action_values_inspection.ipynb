# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ACTIONS_PATH = "recorded_actions"
action_values = np.load(f'{ACTIONS_PATH}/joint_values1.npy')

# %%
for i in range(12):
    plt.plot(action_values[i][0:100], linestyle='-', label=f"Row {i}")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
ACTIONS_PATH = "recorded_actions"
action_values_std_dev = np.load(f'{ACTIONS_PATH}/action_values_std_dev.npy')

# %%
for i in range(12):
    plt.plot(action_values_std_dev[i][60:200], linestyle='-', label=f"Row {i}")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
ACTIONS_PATH = "recorded_actions"
trot_values_std_dev = np.load(f'{ACTIONS_PATH}/trot_actions_std_dev.npy')

# %%
for i in range(12):
    plt.plot(trot_values_std_dev[i][200:1000], linestyle='-', label=f"Row {i}")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
ACTIONS_PATH = "recorded_actions"
trot_values = np.load(f'{ACTIONS_PATH}/trot_actions.npy')

# %%
for i in range(12):
    plt.plot(trot_values[i][200:1000], linestyle='-', label=f"Row {i}")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
ACTIONS_PATH = "recorded_actions"
vel_values = np.load(f'{ACTIONS_PATH}/vel_values.npy')

# %%
# for i in range(12):
#     plt.plot(vel_values[i][200:220], linestyle='-', label=f"Row {i}")
i=5
plt.plot(vel_values[i][200:300], linestyle='-', label=f"Row {i}")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
ACTIONS_PATH = "recorded_actions"
trot_vels = np.load(f'{ACTIONS_PATH}/trot_vels.npy')

# %%
i=5
plt.plot(trot_vels[i][0:300], linestyle='-', label=f"Row {i}")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.legend()
plt.show()
